# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('../DATA/feature_enginerring_complete.csv')

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 POSTED_BY  RERA  BHK_NO.  SQUARE_FT  \
# 0             0           0     Owner     0        2    1300.24
# 1             1           1    Dealer     0        2    1275.00
# 2             2           2     Owner     0        2     933.16
# 3             3           3     Owner     1        2     929.92
# 4             4           4    Dealer     0        2     999.01
#
#                        ADDRESS  LONGITUDE  LATITUDE  TARGET(PRICE_IN_LACS)  \
# 0        Ksfc Layout,Bangalore      77.60     12.97                   55.0
# 1    Vishweshwara Nagar,Mysore      76.64     12.27                   51.0
# 2             Jigani,Bangalore      77.63     12.78                   43.0
# 3  Sector-1 Vaishali,Ghaziabad      77.34     28.64                   62.5
# 4             New Town,Kolkata      88.48     22.59                   60.5
#
#    transformed_price  PRICE_PER_SQFT  LAT_ROUNDED  LONG_ROUNDED
# 0          -0.090412         0.04230        12.97         77.60
# 1          -0.193468         0.04000        12.27         76.64
# 2          -0.430344         0.04608        12.78         77.63
# 3           0.081580         0.06721        28.64         77.34
# 4           0.038118         0.06056        22.59         88.48

# %%
## Independent and dependent feature
X = df.drop(['TARGET(PRICE_IN_LACS)', 'ADDRESS'], axis=1)
y = df['TARGET(PRICE_IN_LACS)']

# %%
X.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 POSTED_BY  RERA  BHK_NO.  SQUARE_FT  LONGITUDE  \
# 0             0           0     Owner     0        2    1300.24      77.60
# 1             1           1    Dealer     0        2    1275.00      76.64
# 2             2           2     Owner     0        2     933.16      77.63
# 3             3           3     Owner     1        2     929.92      77.34
# 4             4           4    Dealer     0        2     999.01      88.48
#
#    LATITUDE  transformed_price  PRICE_PER_SQFT  LAT_ROUNDED  LONG_ROUNDED
# 0     12.97          -0.090412         0.04230        12.97         77.60
# 1     12.27          -0.193468         0.04000        12.27         76.64
# 2     12.78          -0.430344         0.04608        12.78         77.63
# 3     28.64           0.081580         0.06721        28.64         77.34
# 4     22.59           0.038118         0.06056        22.59         88.48

# %%
y
# Out:
# 0        55.0
# 1        51.0
# 2        43.0
# 3        62.5
# 4        60.5
#          ...
# 27098    40.0
# 27099    45.0
# 27100    27.1
# 27101    67.0
# 27102    27.8
# Name: TARGET(PRICE_IN_LACS), Length: 27103, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((20327, 12), (6776, 12))

# %%
X_train.select_dtypes(include=['number']).corr()
# Out:
#                    Unnamed: 0.1  Unnamed: 0      RERA   BHK_NO.  SQUARE_FT  \
# Unnamed: 0.1           1.000000    1.000000 -0.005455  0.005399   0.005444
# Unnamed: 0             1.000000    1.000000 -0.005455  0.005399   0.005444
# RERA                  -0.005455   -0.005455  1.000000  0.015867   0.010811
# BHK_NO.                0.005399    0.005399  0.015867  1.000000   0.775494
# SQUARE_FT              0.005444    0.005444  0.010811  0.775494   1.000000
# LONGITUDE              0.012430    0.012430 -0.205989  0.146093   0.064819
# LATITUDE               0.001802    0.001802  0.117866  0.092499   0.087865
# transformed_price      0.006720    0.006720  0.155745  0.440156   0.516670
# PRICE_PER_SQFT         0.009553    0.009553  0.124863  0.034133  -0.011456
# LAT_ROUNDED            0.001802    0.001802  0.117866  0.092499   0.087865
# LONG_ROUNDED           0.012430    0.012430 -0.205989  0.146093   0.064819
#
#                    LONGITUDE  LATITUDE  transformed_price  PRICE_PER_SQFT  \
# Unnamed: 0.1        0.012430  0.001802           0.006720        0.009553
# Unnamed: 0          0.012430  0.001802           0.006720        0.009553
# RERA               -0.205989  0.117866           0.155745        0.124863
# BHK_NO.             0.146093  0.092499           0.440156        0.034133
# SQUARE_FT           0.064819  0.087865           0.516670       -0.011456
# LONGITUDE           1.000000  0.096396          -0.189931       -0.250136
# LATITUDE            0.096396  1.000000          -0.155677       -0.112611
# transformed_price  -0.189931 -0.155677           1.000000        0.634977
# PRICE_PER_SQFT     -0.250136 -0.112611           0.634977        1.000000
# LAT_ROUNDED         0.096396  1.000000          -0.155677       -0.112611
# LONG_ROUNDED        1.000000  0.096396          -0.189931       -0.250136
#
#                    LAT_ROUNDED  LONG_ROUNDED
# Unnamed: 0.1          0.001802      0.012430
# Unnamed: 0            0.001802      0.012430
# RERA                  0.117866     -0.205989
# BHK_NO.               0.092499      0.146093
# SQUARE_FT             0.087865      0.064819
# LONGITUDE             0.096396      1.000000
# LATITUDE              1.000000      0.096396
# transformed_price    -0.155677     -0.189931
# PRICE_PER_SQFT       -0.112611     -0.250136
# LAT_ROUNDED           1.000000      0.096396
# LONG_ROUNDED          0.096396      1.000000

# %%
import seaborn as sns
plt.figure(figsize=(12,10))
corr = X_train.select_dtypes(include=['number']).corr()
sns.heatmap(corr,annot=True)
plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features=correlation( X_train.select_dtypes(include=['number']).corr(),0.75)

# %%
print(corr_features)
# Out:
# {'LONG_ROUNDED', 'LAT_ROUNDED', 'Unnamed: 0', 'SQUARE_FT', 'PRICE_PER_SQFT'}

# %%
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)
X_train.shape,X_test.shape
# Out:
# ((20327, 7), (6776, 7))

# %%
from sklearn.preprocessing import StandardScaler

# Select numeric columns only
X_train_numeric = X_train.select_dtypes(include=['number'])
X_test_numeric = X_test.select_dtypes(include=['number'])

# Scale them
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_numeric)
X_test_scaled = scaler.transform(X_test_numeric)

# %%
X_train_scaled
# Out:
# array([[-0.11164691,  1.48106668,  0.92467474,  0.03268301,  1.30158216,
#         -0.27638389],
#        [ 1.08183681,  1.48106668, -1.73517999, -1.0427635 , -0.3523191 ,
#          0.67500765],
#        [ 1.04673435, -0.67518904, -0.40525262, -1.10700478,  0.35502056,
#          0.09267608],
#        ...,
#        [-1.62181867, -0.67518904, -0.40525262, -0.99993599, -0.35404012,
#          1.09562726],
#        [ 0.28456415, -0.67518904, -0.40525262,  0.03506232,  1.29469808,
#         -0.53170626],
#        [ 1.28772871, -0.67518904, -1.73517999, -1.04990142, -0.31445664,
#         -0.57131093]], shape=(20327, 6))

# %%
plt.subplots(figsize=(15,5))
plt.subplot(1 , 2, 1)
sns.boxplot(data=X_train)
plt.title('x_train before scaling')
plt.subplot(1 , 2, 2)
sns.boxplot(data=X_train_scaled)
plt.title('x_train after scaling')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
linreg=LinearRegression()
linreg.fit(X_train_scaled,y_train)
y_pred=linreg.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("r2_score",score)
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# Mean absolute error 33.48966467112485
# r2_score 0.5155269694013386

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lasso=Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred=lasso.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("r2_score",score)
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# Mean absolute error 33.12246142187163
# r2_score 0.5146585711176641

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge=Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred=ridge.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("r2_score",score)
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# Mean absolute error 33.48840247250802
# r2_score 0.5155253545865939

# %%
from sklearn.linear_model import LassoCV
lassocv=LassoCV(cv=5)
lassocv.fit(X_train_scaled,y_train)
# Out:
# LassoCV(cv=5)

# %%
lassocv.predict(X_test_scaled)
# Out:
# array([113.42656125,  54.73405949, 270.72313009, ...,  25.8204789 ,
#        -26.464002  ,  59.26128214], shape=(6776,))

# %%
lassocv.alphas_
# Out:
# array([74.63178167, 69.60184937, 64.91091767, 60.53613907, 56.4562059 ,
#        52.65124658, 49.10272878, 45.7933692 , 42.70704938, 39.82873719,
#        37.1444136 , 34.64100444, 32.30631668, 30.12897906, 28.09838671,
#        26.20464949, 24.43854382, 22.79146776, 21.25539911, 19.82285635,
#        18.48686218, 17.24090954, 16.07892994, 14.99526388, 13.98463328,
#        13.0421158 , 12.16312085, 11.34336721, 10.57886222,  9.86588232,
#         9.20095487,  8.58084131,  8.00252132,  7.46317817,  6.96018494,
#         6.49109177,  6.05361391,  5.64562059,  5.26512466,  4.91027288,
#         4.57933692,  4.27070494,  3.98287372,  3.71444136,  3.46410044,
#         3.23063167,  3.01289791,  2.80983867,  2.62046495,  2.44385438,
#         2.27914678,  2.12553991,  1.98228564,  1.84868622,  1.72409095,
#         1.60789299,  1.49952639,  1.39846333,  1.30421158,  1.21631208,
#         1.13433672,  1.05788622,  0.98658823,  0.92009549,  0.85808413,
#         0.80025213,  0.74631782,  0.69601849,  0.64910918,  0.60536139,
#         0.56456206,  0.52651247,  0.49102729,  0.45793369,  0.42707049,
#         0.39828737,  0.37144414,  0.34641004,  0.32306317,  0.30128979,
#         0.28098387,  0.26204649,  0.24438544,  0.22791468,  0.21255399,
#         0.19822856,  0.18486862,  0.1724091 ,  0.1607893 ,  0.14995264,
#         0.13984633,  0.13042116,  0.12163121,  0.11343367,  0.10578862,
#         0.09865882,  0.09200955,  0.08580841,  0.08002521,  0.07463178])

# %%
lassocv.mse_path_
# Out:
# array([[14021.12899969, 11497.42291875,  9327.90939688,  9912.07612614,
#          9286.64553682],
#        [13406.51697963, 10850.9810883 ,  8625.35822212,  9196.06844814,
#          8622.47007033],
#        [12726.12646831, 10182.25275856,  8015.43197264,  8574.99597456,
#          8046.13633451],
#        [12131.77561997,  9599.34100477,  7485.99088192,  8036.38044531,
.predict(X_test_scaled)
plt.scatter(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("r2_score",score)
plt.show()
# Out:
# Mean absolute error 33.45912075578289
# r2_score 0.5154960962486808

# %%
from sklearn.linear_model import RidgeCV
ridgecv=RidgeCV(cv=5)
ridgecv.fit(X_train_scaled,y_train)
y_pred=ridgecv.predict(X_test_scaled)
plt.scatter(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("r2_score",score)
plt.show()
# Out:
# Mean absolute error 33.47705004241966
# r2_score 0.5155106800081994

# %%
ridgecv.alphas
# Out:
# (0.1, 1.0, 10.0)

# %%
ridgecv.get_params()
# Out:
# {'alpha_per_target': False,
#  'alphas': (0.1, 1.0, 10.0),
#  'cv': 5,
#  'fit_intercept': True,
#  'gcv_mode': None,
#  'scoring': None,
#  'store_cv_results': False}

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
elastic=ElasticNet()
elastic.fit(X_train_scaled,y_train)
y_pred=elastic.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("r2_score",score)
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# Mean absolute error 29.896762830488836
# r2_score 0.4521884151085289

# %%
from sklearn.linear_model import ElasticNetCV
elasticcv=ElasticNetCV(cv=5)
elasticcv.fit(X_train_scaled,y_train)
y_pred=elasticcv.predict(X_test_scaled)
plt.scatter(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("r2_score",score)
plt.show()
# Out:
# Mean absolute error 31.937594618039455
# r2_score 0.5102674989004043

# %%
elasticcv.alphas_
# Out:
# array([149.26356334, 139.20369874, 129.82183534, 121.07227814,
#        112.91241181, 105.30249315,  98.20545755,  91.58673839,
#         85.41409876,  79.65747437,  74.2888272 ,  69.28200889,
#         64.61263337,  60.25795813,  56.19677343,  52.40929898,
#         48.87708764,  45.58293552,  42.51079822,  39.6457127 ,
#         36.97372436,  34.48181908,  32.15785988,  29.99052775,
#         27.96926656,  26.0842316 ,  24.32624169,  22.68673442,
#         21.15772445,  19.73176463,  18.40190974,  17.16168261,
#         16.00504264,  14.92635633,  13.92036987,  12.98218353,
#         12.10722781,  11.29124118,  10.53024932,   9.82054576,
#          9.15867384,   8.54140988,   7.96574744,   7.42888272,
#          6.92820089,   6.46126334,   6.02579581,   5.61967734,
#          5.2409299 ,   4.88770876,   4.55829355,   4.25107982,
#          3.96457127,   3.69737244,   3.44818191,   3.21578599,
#          2.99905278,   2.79692666,   2.60842316,   2.43262417,
#          2.26867344,   2.11577244,   1.97317646,   1.84019097,
#          1.71616826,   1.60050426,   1.49263563,   1.39203699,
#          1.29821835,   1.21072278,   1.12912412,   1.05302493,
#          0.98205458,   0.91586738,   0.85414099,   0.79657474,
#          0.74288827,   0.69282009,   0.64612633,   0.60257958,
#          0.56196773,   0.52409299,   0.48877088,   0.45582936,
#          0.42510798,   0.39645713,   0.36973724,   0.34481819,
#          0.3215786 ,   0.29990528,   0.27969267,   0.26084232,
#          0.24326242,   0.22686734,   0.21157724,   0.19731765,
#          0.1840191 ,   0.17161683,   0.16005043,   0.14926356])

# %%
scaler
# Out:
# StandardScaler()

# %%
ridge
# Out:
# Ridge()

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(ridge,open('ridge.pkl','wb'))
